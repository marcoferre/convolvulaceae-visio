# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# Setting the random seed for all the successive randomized operations
SEED = 1234
tf.random.set_seed(SEED)
np.random.seed(SEED)

# Is GPU Working?
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Obtain the Dataset and the GloVe Embedding through a Drive Direct Download link.

# %%
# !wget --no-check-certificate -r "https://drive.google.com/uc?export=download&id=1yXMBQWxGvTYmndxuREZ9N86l1s43lFRt" -O "BRM-emot-submit-val-arousal.csv"
# !wget --no-check-certificate -r "https://drive.google.com/uc?export=download&id=1XlfVSprLu3nj3_hsuAui2d1inFTnhFPX" -O "imagenet1000_clsidx_to_labels.json"
# !wget --no-check-certificate -r "https://drive.google.com/uc?export=download&id=1GXqL5zG0PHjX1BDATQCiLRIODKuSpOVn" -O "Glove.zip"

# !unzip "/content/Glove.zip"
# Out:
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2021-09-08 11:25:03--  https://drive.google.com/uc?export=download&id=1yXMBQWxGvTYmndxuREZ9N86l1s43lFRt
# Resolving drive.google.com (drive.google.com)... 142.251.8.139, 142.251.8.102, 142.251.8.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-4c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ete4ri8fu1mrbuger2enrs3mlaka0gtc/1631100300000/16730855647952832235/*/1yXMBQWxGvTYmndxuREZ9N86l1s43lFRt?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-09-08 11:25:05--  https://doc-10-4c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ete4ri8fu1mrbuger2enrs3mlaka0gtc/1631100300000/16730855647952832235/*/1yXMBQWxGvTYmndxuREZ9N86l1s43lFRt?e=download
# Resolving doc-10-4c-docs.googleusercontent.com (doc-10-4c-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-10-4c-docs.googleusercontent.com (doc-10-4c-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘BRM-emot-submit-val-arousal.csv’
#
# BRM-emot-submit-val     [ <=>                ]   3.56M  --.-KB/s    in 0.03s
#
# 2021-09-08 11:25:06 (122 MB/s) - ‘BRM-emot-submit-val-arousal.csv’ saved [3736799]
#
# FINISHED --2021-09-08 11:25:06--
# Total wall clock time: 3.1s
# Downloaded: 1 files, 3.6M in 0.03s (122 MB/s)
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2021-09-08 11:25:06--  https://drive.google.com/uc?export=download&id=1XlfVSprLu3nj3_hsuAui2d1inFTnhFPX
# Resolving drive.google.com (drive.google.com)... 142.251.8.139, 142.251.8.102, 142.251.8.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-9c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/i2mpdlf64m542lrml0sc5mr9f0r64j5v/1631100300000/17562262531043783088/*/1XlfVSprLu3nj3_hsuAui2d1inFTnhFPX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-09-08 11:25:07--  https://doc-04-9c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/i2mpdlf64m542lrml0sc5mr9f0r64j5v/1631100300000/17562262531043783088/*/1XlfVSprLu3nj3_hsuAui2d1inFTnhFPX?e=download
# Resolving doc-04-9c-docs.googleusercontent.com (doc-04-9c-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-04-9c-docs.googleusercontent.com (doc-04-9c-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34568 (34K) [application/json]
# Saving to: ‘imagenet1000_clsidx_to_labels.json’
#
# imagenet1000_clsidx 100%[===================>]  33.76K  --.-KB/s    in 0.001s
#
# 2021-09-08 11:25:07 (41.3 MB/s) - ‘imagenet1000_clsidx_to_labels.json’ saved [34568/34568]
#
# FINISHED --2021-09-08 11:25:07--
# Total wall clock time: 1.2s
# Downloaded: 1 files, 34K in 0.001s (41.3 MB/s)
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2021-09-08 11:25:07--  https://drive.google.com/uc?export=download&id=1GXqL5zG0PHjX1BDATQCiLRIODKuSpOVn
# Resolving drive.google.com (drive.google.com)... 142.251.8.101, 142.251.8.139, 142.251.8.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Glove.zip’
#
# Glove.zip               [ <=>                ]   3.21K  --.-KB/s    in 0s
#
# 2021-09-08 11:25:08 (34.5 MB/s) - ‘Glove.zip’ saved [3283]
#
# Loading robots.txt; please ignore errors.
# --2021-09-08 11:25:08--  https://drive.google.com/robots.txt
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘Glove.zip’
#
# Glove.zip               [ <=>                ]     570  --.-KB/s    in 0s
#
# 2021-09-08 11:25:09 (59.7 MB/s) - ‘Glove.zip’ saved [570]
#
# --2021-09-08 11:25:09--  https://drive.google.com/static/doclist/client/css/3020215093-untrustedcontent.css
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 190108 (186K) [text/css]
# Saving to: ‘Glove.zip’
#
# Glove.zip           100%[===================>] 185.65K  --.-KB/s    in 0.003s
#
# 2021-09-08 11:25:09 (65.8 MB/s) - ‘Glove.zip’ saved [190108/190108]
#
# --2021-09-08 11:25:09--  https://drive.google.com/settings?hl=en_US
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://drive.google.com/settings?hl%3Den_US&followup=https://drive.google.com/settings?hl%3Den_US&hl=en_US [following]
# --2021-09-08 11:25:09--  https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://drive.google.com/settings?hl%3Den_US&followup=https://drive.google.com/settings?hl%3Den_US&hl=en_US
# Resolving accounts.google.com (accounts.google.com)... 74.125.203.84, 2404:6800:4008:c07::54
# Connecting to accounts.google.com (accounts.google.com)|74.125.203.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Glove.zip’
#
# Glove.zip               [ <=>                ]  89.91K  --.-KB/s    in 0.003s
#
# 2021-09-08 11:25:09 (31.0 MB/s) - ‘Glove.zip’ saved [92072]
#
# --2021-09-08 11:25:09--  https://drive.google.com/open?id=1GXqL5zG0PHjX1BDATQCiLRIODKuSpOVn
# Connecting to drive.google.com (drive.google.com)|142.251.8.101|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://drive.google.com/file/d/1GXqL5zG0PHjX1BDATQCiLRIODKuSpOVn/view?usp=drive_open [following]
# --2021-09-08 11:25:10--  https://drive.google.com/file/d/1GXqL5zG0PHjX1BDATQCiLRIODKuSpOVn/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: �
203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip-compressed]
# Saving to: ‘Glove.zip’
#
# Glove.zip               [           <=>      ] 822.24M  59.0MB/s    in 14s
#
# 2021-09-08 11:25:26 (60.4 MB/s) - ‘Glove.zip’ saved [862182753]
#
# FINISHED --2021-09-08 11:25:26--
# Total wall clock time: 19s
# Downloaded: 6 files, 823M in 14s (59.8 MB/s)
# Archive:  /content/Glove.zip
# warning [/content/Glove.zip]:  352243 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
#   inflating: glove.6B.50d.txt

# %% [markdown]
# Read the BRM Dataset into a Pandas Dataframe: from all the available columns we retain only the mean Valence and Arousal values.

# %%
df = pd.read_csv('BRM-emot-submit-val-arousal.csv')

df = df[['Word', 'V.Mean.Sum', 'A.Mean.Sum']].astype(str)
df.head()
# Out:
#           Word V.Mean.Sum A.Mean.Sum
# 0     aardvark       6.26       2.41
# 1      abalone        5.3       2.65
# 2      abandon       2.84       3.73
# 3  abandonment       2.63       4.95
# 4        abbey       5.85        2.2

# %% [markdown]
# Building the training set extracting from the DataFrame all the words in a list.

# %%
text = df['Word'].tolist()

# %% [markdown]
# Building the traininig regression values.

# %%
y = df[['V.Mean.Sum', 'A.Mean.Sum']]

# Scale the Valence and Arousal values between -1 and 1
scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
y = scaler.fit_transform(y)

# %% [markdown]
# # Read the the GloVe Embedding from file
# GloVe is an unsupervised learning algorithm for obtaining vector representations for words. Training is performed on aggregated global word-word co-occurrence statistics from a corpus, and the resulting representations showcase interesting linear substructures of the word vector space.

# %%
glove_vectors = dict()

file = open('glove.6B.200d.txt', encoding='utf-8')

for line in file:
    values = line.split()
    word = values[0]
    vectors = np.asarray(values[1:])
    glove_vectors[word] = vectors
file.close()

# %%
len(glove_vectors.keys())
# Out:
# 400001

# %% [markdown]
# # Apply the Tokenization to GloVe
#
# Build a dictionary using the the words contained in GloVe then apply tokenization

# %%
# Build the dictionary
glove_dict = list(glove_vectors.keys())

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# Apply the Tokenization to the GloVe dictionary
token = Tokenizer()
token.fit_on_texts(glove_dict)

# %%
vocab_size = len(token.word_index) + 1
vocab_size
# Out:
# 339252

# %%
# Apply the Tokenization for each sequence in the training set
encoded_text = token.texts_to_sequences(text)

# %%
# Pad the sequence to a maximum length of 5 adding zeros
max_length = 5
X = tf.keras.preprocessing.sequence.pad_sequences(encoded_text, maxlen=max_length, padding='post')

# %%
# Build the embedding matrix picking the embedding values from the GloVe dictionary
word_vector_matrix = np.zeros((vocab_size, 200))

for word, index in token.word_index.items():
    vector = glove_vectors.get(word)
    word_vector_matrix[index] = vector

# %% [markdown]
# # Split the Training Set in Training and Validation Data
# We used the sklearn `train_test_split` method to split the training data into "training set" and "validation set". The proportion for the split is:
# *   90% for training
# *   5% for validation
# *   5% for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=SEED, test_size=0.05)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=SEED, test_size=0.05)

# %% [markdown]
# # Building the Regressor Model
# On top of the Embedding Layer (embedding dimension of 200), build the Regression Network:
# *  Conv1D(64, 8)
# *  MaxPooling1D(2)
# *  GlobalAveragingPooling1D
# *  Dense(256)
# *  Dense(128)

# %%
vec_size = 200

lr = 1e-4
dropout= 0.5

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Embedding(vocab_size, vec_size, input_length=max_length, weights=[word_vector_matrix], trainable=False))

model.add(tf.keras.layers.Conv1D(64, 8, activation='relu', padding="same"))
model.add(tf.keras.layers.MaxPooling1D(2))
model.add(tf.keras.layers.Dropout(dropout))

model.add(tf.keras.layers.GlobalAveragePooling1D())

model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(dropout))

model.add(tf.keras.layers.Dense(128, activation='relu'))

model.add(tf.keras.layers.Dense(2, activation='linear'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 5, 200)            67850400
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 5, 64)             102464
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2, 64)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 64)             0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 256)               16640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 68,002,658
# Trainable params: 152,258
# Non-trainable params: 67,850,400
# _________________________________________________________________

# %% [markdown]
# Defining the Loss Function and the Optimizer to be used during training.

# %%
loss = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# %%
# Validation metrics
# ------------------
metrics = [tf.keras.metrics.MeanSquaredError()]

# %% [markdown]
# Compiling the Model.

# %%
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
model.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 393/393 [==============================] - 31s 5ms/step - loss: 0.0992 - mean_squared_error: 0.0992 - val_loss: 0.0807 - val_mean_squared_error: 0.0807
# Epoch 2/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0800 - mean_squared_error: 0.0800 - val_loss: 0.0716 - val_mean_squared_error: 0.0716
# Epoch 3/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0718 - mean_squared_error: 0.0718 - val_loss: 0.0678 - val_mean_squared_error: 0.0678
# Epoch 4/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0677 - mean_squared_error: 0.0677 - val_loss: 0.0652 - val_mean_squared_error: 0.0652
# Epoch 5/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.0643 - val_mean_squared_error: 0.0643
# Epoch 6/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0623 - mean_squared_error: 0.0623 - val_loss: 0.0632 - val_mean_squared_error: 0.0632
# Epoch 7/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0608 - mean_squared_error: 0.0608 - val_loss: 0.0623 - val_mean_squared_error: 0.0623
# Epoch 8/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0590 - mean_squared_error: 0.0590 - val_loss: 0.0615 - val_mean_squared_error: 0.0615
# Epoch 9/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0578 - mean_squared_error: 0.0578 - val_loss: 0.0605 - val_mean_squared_error: 0.0605
# Epoch 10/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0568 - mean_squared_error: 0.0568 - val_loss: 0.0602 - val_mean_squared_error: 0.0602
# Epoch 11/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.0598 - val_mean_squared_error: 0.0598
# Epoch 12/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0543 - mean_squared_error: 0.0543 - val_loss: 0.0594 - val_mean_squared_error: 0.0594
# Epoch 13/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0535 - mean_squared_error: 0.0535 - val_loss: 0.0588 - val_mean_squared_error: 0.0588
# Epoch 14/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.0583 - val_mean_squared_error: 0.0583
# Epoch 15/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0518 - mean_squared_error: 0.0518 - val_loss: 0.0577 - val_mean_squared_error: 0.0577
# Epoch 16/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0514 - mean_squared_error: 0.0514 - val_loss: 0.0575 - val_mean_squared_error: 0.0575
# Epoch 17/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0507 - mean_squared_error: 0.0507 - val_loss: 0.0576 - val_mean_squared_error: 0.0576
# Epoch 18/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0575 - val_mean_squared_error: 0.0575
# Epoch 19/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0485 - mean_squared_error: 0.0485 - val_loss: 0.0571 - val_mean_squared_error: 0.0571
# Epoch 20/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0564 - val_mean_squared_error: 0.0564
# Epoch 21/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.0564 - val_mean_squared_error: 0.0564
# Epoch 22/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0466 - mean_squared_error: 0.0466 - val_loss: 0.0566 - val_mean_squared_error: 0.0566
# Epoch 23/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0452 - mean_squared_error: 0.0452 - val_loss: 0.0561 - val_mean_squared_error: 0.0561
# Epoch 24/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0453 - mean_squared_error: 0.0453 - val_loss: 0.0564 - val_mean_squared_error: 0.0564
# Epoch 25/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0445 - mean_squared_error: 0.0445 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 26/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0436 - mean_squared_error: 0.0436 - val_loss: 0.0561 - val_mean_squared_error: 0.0561
# Epoch 27/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.0556 - val_mean_squared_error: 0.0556
# Epoch 28/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 29/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0423 - mean_squared_error: 0.0423 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 30/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0556 - val_mean_squared_error: 0.0556
# Epoch 31/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 0.0558 - val_mean_squared_error: 0.0558
# Epoch 32/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0555 - val_mean_squared_error: 0.0555
# Epoch 33/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0558 - val_mean_squared_error: 0.0558
# Epoch 34/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 35/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0556 - val_mean_squared_error: 0.0556
# Epoch 36/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0557 - val_mean_squared_error: 0.0557
# Epoch 37/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0559 - val_mean_squared_error: 0.0559
# Epoch 38/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 39/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 40/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0370 - mean_squared_error: 0.0370 - val_loss: 0.0564 - val_mean_squared_error: 0.0564
# Epoch 41/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 42/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 43/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0557 - val_mean_squared_error: 0.0557
# Epoch 44/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 45/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0561 - val_mean_squared_error: 0.0561
# Epoch 46/50
# 393/393 [==============================] - 2s 4ms/step - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 47/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 48/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Epoch 49/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 50/50
# 393/393 [==============================] - 2s 5ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0560 - val_mean_squared_error: 0.0560

# %% [markdown]
# # Inference on the Test Set
# We perform an inference on the test set to evaluate the regression performance.

# %%
# Before predictions, data needs to be properly encoded
def get_encode(x):
    x = token.texts_to_sequences(x)
    x = tf.keras.preprocessing.sequence.pad_sequences(x, maxlen=max_length, padding='post')
    return x

# %%
# Generate predictions
preds = model.predict(X_test)
# Generate baseline predictions
preds_baseline = np.zeros(y_test.shape) + np.mean(y,axis=0)

# %%
# Mean Absolute Error for predictions
mae = np.mean(np.abs(preds - y_test),axis=0)
# Mean Squared Error for predictions
mse = np.mean(np.square(preds - y_test),axis=0)

# Mean Absolute Error for baseline 
mae_baseline = np.mean(np.abs(preds_baseline - y_test),axis=0)
# Mean Squared Error for baseline 
mse_baseline = np.mean(np.square(preds_baseline - y_test),axis=0)

print('Valence Mean Absolute Error: ' , mae[0], ' VS ', 'Baseline: ', mae_baseline[0], '\n')
print('Arousal Mean Absolute Error: ' , mae[1], ' VS ', 'Baseline: ', mae_baseline[1], '\n')

print('Valence Mean Squared Error: ' , mse[0], ' VS ', 'Baseline: ', mse_baseline[0], '\n')
print('Arousal Mean Squared Error: ' , mse[1], ' VS ', 'Baseline: ', mse_baseline[1], '\n')
# Out:
# Valence Mean Absolute Error:  0.1719224657281219  VS  Baseline:  0.28411726162564677
#
# Arousal Mean Absolute Error:  0.18310803658288619  VS  Baseline:  0.22336753658178057
#
# Valence Mean Squared Error:  0.049909606709977385  VS  Baseline:  0.12174314478951893
#
# Arousal Mean Squared Error:  0.0526859644835051  VS  Baseline:  0.07798782065098707

# %%
print(model.name , 'Coefficient of determination R2:' , 1 - mse/mse_baseline )
# Out:
# sequential_1 Coefficient of determination R2: [0.59004175 0.32443343]

# %% [markdown]
#  # Inference on ImageNet
#  The following code infers the Valence and Arousal values for the class labels contained in *ImageNet*

# %% [markdown]
# Open the ImageNet list of class labels and extract their values in a list

# %%
import json

with open('imagenet1000_clsidx_to_labels.json') as json_file:
    imagenet_classes = json.load(json_file)

imagenet_filtered_classes = dict()

for key, value in imagenet_classes.items():
    str_list = value.split(',')
    imagenet_filtered_classes[key] = str_list[0]

# %% [markdown]
# Apply the Regression model to the ImageNet Classes

# %%
imagenet_va = dict()

for key, value in imagenet_filtered_classes.items():
    imagenet_va[key] = model.predict(get_encode([value]))[0]

# %%
imagenet_va
# Out:
# {'0': array([-0.03559431, -0.2518264 ], dtype=float32),
#  '601': array([-0.04725845,  0.06197202], dtype=float32),
#  '602': array([ 0.10372757, -0.36114708], dtype=float32),
#  '603': array([ 0.18327896, -0.3626765 ], dtype=float32),
#  '604': array([ 0.15247172, -0.34399036], dtype=float32),
#  '605': array([ 0.3130567 , -0.20236176], dtype=float32),
#  '606': array([ 0.1100207, -0.3707426], dtype=float32),
#  '607': array([ 0.2033105, -0.2946417], dtype=float32),
#  '608': array([ 0.15431175, -0.3392674 ], dtype=float32),
#  '609': array([ 0.20814921, -0.25448927], dtype=float32),
#  '610': array([ 0.15497519, -0.27211347], dtype=float32),
#  '611': array([ 0.25035006, -0.15642898], dtype=float32),
#  '612': array([-0.04725845,  0.06197202], dtype=float32),
#  '613': array([ 0.21288782, -0.2433021 ], dtype=float32),
#  '614': array([ 0.2928952 , -0.22647958], dtype=float32),
#  '615': array([ 0.03902259, -0.35466155], dtype=float32),
#  '616': array([ 0.09192303, -0.30606875], dtype=float32),
#  '617': array([ 0.16711695, -0.4050263 ], dtype=float32),
#  '618': array([ 0.07055855, -0.42335925], dtype=float32),
#  '619': array([ 0.16422379, -0.31697366], dtype=float32),
#  '620': array([ 0.2950017 , -0.27824166], dtype=float32),
#  '621': array([ 0.16520071, -0.540642  ], dtype=float32),
#  '622': array([ 0.0930643, -0.3401827], dtype=float32),
#  '623': array([ 0.09469259, -0.3688599 ], dtype=float32),
#  '624': array([ 0.31933105, -0.39154455], dtype=float32),
#  '625': array([ 0.08596695, -0.31516716], dtype=float32),
#  '626': array([ 0.2085968 , -0.30630842], dtype=float32),
#  '627': array([0.20659691, 0.03448317], dtype=float32),
#  '628': array([ 0.11469121, -0.32096913], dtype=float32),
#  '629': array([ 0.30037415, -0.23501495], dtype=float32),
#  '630': array([ 0.08008474, -0.2973432 ], dtype=float32),
#  '631': array([ 0.17171788, -0.326842  ], dtype=float32),
#  '632': array([ 0.06489137, -0.27391136], dtype=float32),
#  '633': array([ 0.13114358, -0.34115776], dtype=float32),
#  '634': array([-0.04725845,  0.06197202], dtype=float32),
#  '635': array([ 0.15426338, -0.28541076], dtype=float32),
#  '636': array([ 0.13465849, -0.33926857], dtype=float32),
#  '637': array([ 0.20884778, -0.39842153], dtype=float32),
#  '638': array([ 0.07798378, -0.29625624], dtype=float32),
#  '639': array([ 0.07798378, -0.29625624], dtype=float32),
#  '640': array([ 0.00378504, -0.36537585], dtype=float32),
#  '641': array([ 0.03128315, -0.2696691 ], dtype=float32),
#  '642': array([ 0.15182628, -0.2711583 ], dtype=float32),
#  '643': array([ 0.12725084, -0.3428751 ], dtype=float32),
#  '644': array([ 0.08138178, -0.21365151], dtype=float32),
#  '645': array([ 0.2589512 , -0.20698848], dtype=float32),
#  '646': array([ 0.13680844, -0.06090635], dtype=float32),
#  '647': array([ 0.14335394, -0.34316456], dtype=float32),
#  '648': array([ 0.06923923, -0.2985488 ], dtype=float32),
#  '649': array([ 0.20561008, -0.21293436], dtype=float32),
#  '650': array([ 0.11176595, -0.3524078 ], dtype=float32),
#  '701': array([ 0.12603773, -0.03575684], dtype=float32),
#  '702': array([ 0.15319592, -0.2547156 ], dtype=float32),
#  '703': array([ 0.32224017, -0.4120372 ], dtype=float32),
#  '704': array([ 0.01113808, -0.3410716 ], dtype=float32),
#  '705': array([ 0.13941397, -0.31924877], dtype=float32),
#  '706': array([ 0.33489105, -0.47180736], dtype=float32),
#  '707': array([ 0.14075837, -0.45644644], dtype=float32),
#  '708': array([ 0.11750823, -0.37402487], dtype=float32),
#  '709': array([ 0.1845909, -0.4065515], dtype=float32),
#  '710': array([ 0.18945213, -0.34782872], dtype=float32),
#  '711': array([ 0.37908965, -0.15598047], dtype=float32),
#  '712': array([ 0.2385029 , -0.46803898], dtype=float32),
#  '713': array([ 0.00859737, -0.33019072], dtype=float32),
#  '714': array([ 0.22079991, -0.29403403], dtype=float32),
#  '715': array([-0.04725845,  0.06197202], dtype=float32),
#  '716': array([ 0.02109295, -0.38426173], dtype=float32),
#  '717': array([ 0.07144742, -0.34865186], dtype=float32),
#  '718': array([ 0.24849367, -0.31959143], dtype=float32),
#  '719': array([ 0.10298427, -0.37757468], dtype=float32),
#  '720': array([ 0.38789576, -0.16067594], dtype=float32),
#  '721': array([ 0.3522871, -0.4237453], dtype=float32),
#  '722': array([ 0.2038782 , -0.29536754], dtype=float32),
#  '723': array([ 0.09754107, -0.2860032 ], dtype=float32),
#  '724': array([-0.01371549, -0.0008233 ], dtype=float32),
#  '725': array([ 0.11117322, -0.3086761 ], dtype=float32),
#  '726': array([ 0.20623338, -0.18049519], dtype=float32),
#  '727': array([ 0.28875408, -0.3291312 ], dtype=float32),
#  '728': array([ 0.19705084, -0.45020103], dtype=float32),
#  '729': array([ 0.15290557, -0.375232  ], dtype=float32),
#  '730': array([ 0.04627563, -0.37887892], dtype=float32),
#  '731': array([-0.04796545, -0.33865973], dtype=float32),
#  '732': array([ 0.20361224, -0.38237783], dtype=float32),
#  '733': array([ 0.1431016 , -0.33901975], dtype=float32),
#  '734': array([-0.04622163, -0.23618536], dtype=float32),
#  '735': array([ 0.14268392, -0.31749997], dtype=float32),
#  '736': array([ 0.21019986, -0.42665407], dtype=float32),
#  '737': array([ 0.37506247, -0.09987004], dtype=float32),
#  '738': array([ 0.14600027, -0.32041672], dtype=float32),
#  '739': array([ 0.14922108, -0.35783902], dtype=float32),
#  '740': array([ 0.11289558, -0.08321877], dtype=float32),
#  '741': array([ 0.20375723, -0.60588026], dtype=float32),
#  '742': array([ 0.1183861 , -0.37972018], dtype=float32),
#  '743': array([-0.5625893 ,  0.14191374], dtype=float32),
#  '744': array([-0.12284827, -0.2134182 ], dtype=float32),
#  '745': array([ 0.21528912, -0.27411827], dtype=float32),
#  '746': array([-0.04655585, -0.23920178], dtype=float32),
#  '747': array([ 0.07749956, -0.3302168 ], dtype=float32),
#  '748': array([ 0.15932322, -0.30795285], dtype=float32),
#  '749': array([ 0.06437038, -0.29420438], dtype=float32),
#  '750': array([ 0.28904867, -0.46804765], dtype=float32),
#  '751': array([0.3182097 , 0.05963963], dtype=float32),
#  '752': array([-0.20531738, -0.21039705], dtype=float32),
#  '753': array([ 0.09666599, -0.38061813], dtype=float32),
#  '754': array([ 0.22835985, -0.23121026], dtype=float32),
#  '755': array([ 0.12721719, -0.25758088], dtype=float32),
#  '756': array([-0.15973914, -0.05152355], dtype=float32),
#  '757': array([ 0.34588096, -0.19043113], dtype=float32),
#  '758': array([ 0.11347713, -0.3159371 ], dtype=float32),
#  '759': array([ 0.21150875, -0.36565784], dtype=float32),
#  '760': array([ 0.18539807, -0.3873163 ], dtype=float32),
#  '761': array([ 0.0908725, -0.3338749], dtype=float32),
#  '762': array([ 0.39988324, -0.1779808 ], dtype=float32),
#  '763': array([-0.35339212,  0.25890267], dtype=float32),
#  '764': array([-0.14230865,  0.2541957 ], dtype=float32),
#  '765': array([ 0.15892038, -0.40526518], dtype=float32),
#  '766': array([ 0.22570452, -0.18737268], dtype=float32),
#  '767': array([ 0.13817306, -0.41778776], dtype=float32),
#  '768': array([ 0.13674271, -0.25435156], dtype=float32),
#  '769': array([-0.01140807, -0.29186612], dtype=float32),
#  '770': array([ 0.22212845, -0.3166161 ], dtype=float32),
#  '771': array([ 0.5445812, -0.3236745], dtype=float32),
#  '772': array([ 0.16633597, -0.37062916], dtype=float32),
#  '773': array([-0.04725845,  0.06197202], dtype=float32),
#  '774': array([ 0.12842134, -0.2765795 ], dtype=float32),
#  '775': array([ 0.16577409, -0.34290114], dtype=float32),
#  '776': array([ 0.13383082, -0.24386363], dtype=float32),
#  '777': array([-0.07666606, -0.30233273], dtype=float32),
#  '778': array([ 0.13695078, -0.23206332], dtype=float32),
#  '779': array([ 0.1585259 , -0.43155822], dtype=float32),
#  '780': array([ 0.19588408, -0.36802077], dtype=float32),
#  '781': array([ 0.13158278, -0.27404836], dtype=float32),
#  '782': array([ 0.25614882, -0.3130287 ], dtype=float32),
#  '783': array([-0.01550589, -0.3385527 ], dtype=float32),
#  '784': array([ 0.06319451, -0.31820577], dtype=float32),
#  '785': array([ 0.07079466, -0.35839108], dtype=float32),
#  '786': array([ 0.29990655, -0.21291843], dtype=float32),
#  '787': array([ 0.05685499, -0.2783426 ], dtype=float32),
#  '788': array([ 0.21849984, -0.441017  ], dtype=float32),
#  '789': array([ 0.03604661, -0.29788032], dtype=float32),
#  '790': array([ 0.25683373, -0.34257627], dtype=float32),
#  '791': array([ 0.26822186, -0.26553372], dtype=float32),
#  '792': array([ 0.04129656, -0.32223457], dtype=float32),
#  '793': array([ 0.29550758, -0.25059488], dtype=float32),
#  '794': array([ 0.30738884, -0.34317198], dtype=float32),
#  '795': array([0.3832024 , 0.30004227], dtype=float32),
#  '796': array([ 0.2830431 , -0.15024233], dtype=float32),
#  '797': array([ 0.38032293, -0.3787646 ], dtype=float32),
#  '798': array([ 0.00651537, -0.3122739 ], dtype=float32),
#  '799': array([ 0.10320677, -0.41630194], dtype=float32),
#  '800': array([ 0.1221863 , -0.27018145], dtype=float32),
#  '801': array([ 0.21231121, -0.20996535], dtype=float32),
#  '802': array([ 0.12283165, -0.22149375], dtype=float32),
#  '803': array([ 0.01670608, -0.30212668], dtype=float32),
#  '804': array([ 0.31337398, -0.32543924], dtype=float32),
#  '805': array([ 0.2877803 , -0.02334735], dtype=float32),
#  '806': array([-0.05435582, -0.3487799 ], dtype=float32),
#  '807': array([ 0.37597656, -0.31586674], dtype=float32),
#  '808': array([ 0.15607269, -0.26174963], dtype=float32),
#  '809': array([ 0.45449466, -0.2786779 ], dtype=float32),
#  '810': array([ 0.31258896, -0.2005517 ], dtype=float32),
#  '811': array([ 0.21619712, -0.40201265], dtype=float32),
#  '812': array([ 0.30651128, -0.31348965], dtype=float32),
#  '813': array([ 0.09933515, -0.4122536 ], dtype=float32),
#  '814': array([0.3867452 , 0.20981747], dtype=float32),
#  '815': array([0.3252467 , 0.27108768], dtype=float32),
#  '816': array([ 0.02762264, -0.3762001 ], dtype=float32),
#  '817': array([ 0.3404581 , -0.06608898], dtype=float32),
#  '818': array([ 0.20580249, -0.04658508], dtype=float32),
#  '819': array([ 0.14069764, -0.2874119 ], dtype=float32),
#  '820': array([ 0.15470044, -0.24153367], dtype=float32),
#  '821': array([ 0.06853088, -0.3736013 ], dtype=float32),
#  '822': array([ 0.08949812, -0.31229115], dtype=float32),
#  '823': array([ 0.14007139, -0.33061415], dtype=float32),
#  '824': array([0.02016702, 0.00818939], dtype=float32),
#  '825': array([ 0.1170132, -0.3935642], dtype=float32),
#  '826': array([ 0.0135127 , -0.20327014], dtype=float32),
#  '827': array([ 0.22299671, -0.33218434], dtype=float32),
#  '828': array([-0.0087491 , -0.37985232], dtype=float32),
#  '829': array([ 0.10493115, -0.31757936], dtype=float32),
#  '830': array([-0.35777646, -0.15702435], dtype=float32),
#  '831': array([ 0.25221702, -0.37322193], dtype=float32),
#  '832': array([ 0.14247876, -0.37453422], dtype=float32),
#  '833': array([ 0.12342398, -0.08241047], dtype=float32),
#  '834': array([ 0.24086973, -0.34172928], dtype=float32),
#  '835': array([ 0.16207181, -0.40218547], dtype=float32),
#  '836': array([ 0.19290465, -0.30021384], dtype=float32),
#  '837': array([ 0.21859634, -0.29440963], dtype=float32),
#  '838': array([ 0.19351578, -0.25469014], dtype=float32),
#  '839': array([ 0.22375014, -0.300751  ], dtype=float32),
#  '840': array([-0.00049641, -0.41927546], dtype=float32),
#  '841': array([ 0.14878118, -0.35090238], dtype=float32),
#  '842': array([ 0.28550476, -0.37805203], dtype=float32),
#  '843': array([ 0.27297428, -0.31821805], dtype=float32),
#  '844': array([ 0.09647691, -0.34878418], dtype=float32),
#  '845': array([-0.37300092, -0.11161356], dtype=float32),
#  '846': array([ 0.21726805, -0.47508857], dtype=float32),
#  '847': array([-0.01812284, -0.20512894], dtype=float32),
#  '848': array([ 6.2999316e-06, -1.9190042e-01], dtype=float32),
#  '849': array([ 0.1819774 , -0.33209133], dtype=float32),
#  '850': array([ 0.30669892, -0.35754657], dtype=float32),
#  '851': array([ 0.22524585, -0.22957969], dtype=float32),
#  '852': array([ 0.23569533, -0.2821648 ], dtype=float32),
#  '853': array([ 0.07435597, -0.48945445], dtype=float32),
#  '854': array([ 0.20519586, -0.3640742 ], dtype=float32),
#  '855': array([ 0.13166308, -0.32080188], dtype=float32),
#  '856': array([-0.02672692, -0.25772634], dtype=float32),
#  '857': array([ 0.14710125, -0.13057889], dtype=float32),
#  '858': array([ 0.13028297, -0.45534348], dtype=float32),
#  '859': array([ 0.3107646 , -0.24485663], dtype=float32),
#  '860': array([ 0.08028606, -0.32823515], dtype=float32),
#  '861': array([ 0.14793515, -0.4918183 ], dtype=float32),
#  '862': array([0.15023041, 0.04150117], dtype=float32),
#  '863': array([ 0.03995267, -0.2989841 ], dtype=float32),
#  '864': array([ 0.01588629, -0.2778545 ], dtype=float32),
#  '865': array([-0.01552491, -0.20277232], dtype=float32),
#  '866': array([ 0.09494817, -0.35913983], dtype=float32),
#  '867': array([-0.20914084, -0.23076577], dtype=float32),
#  '868': array([ 0.15099032, -0.39971837], dtype=float32),
#  '869': array([ 0.13975528, -0.43124267], dtype=float32),
#  '870': array([ 0.11449069, -0.31879908], dtype=float32),
#  '871': array([ 0.12479533, -0.11364847], dtype=float32),
#  '872': array([ 0.0720254, -0.3130696], dtype=float32),
#  '873': array([ 0.06535305, -0.33749023], dtype=float32),
#  '874': array([ 0.0096106 , -0.29802245], dtype=float32),
#  '875': array([ 0.02944021, -0.26711652], dtype=float32),
#  '876': array([ 0.14421506, -0.36112416], dtype=float32),
#  '877': array([ 0.01054356, -0.31087506], dtype=float32),
#  '878': array([ 0.12273383, -0.31861892], dtype=float32),
#  '879': array([ 0.16246101, -0.38838458], dtype=float32),
#  '880': array([-0.11068449, -0.21310073], dtype=float32),
#  '881': array([ 0.13889444, -0.4514363 ], dtype=float32),
#  '882': array([ 0.1426928 , -0.32038137], dtype=float32),
#  '883': array([ 0.18464738, -0.43673232], dtype=float32),
#  '884': array([ 0.09038477, -0.37924352], dtype=float32),
#  '885': array([ 0.31072527, -0.25429094], dtype=float32),
#  '886': array([-0.05715811, -0.21993405], dtype=float32),
#  '887': array([ 0.06497613, -0.35940418], dtype=float32),
#  '888': array([ 0.06224637, -0.35934296], dtype=float32),
#  '889': array([ 0.22449677, -0.3174027 ], dtype=float32),
#  '890': array([ 0.2821685 , -0.14533477], dtype=float32),
#  '891': array([ 0.20981643, -0.31539798], dtype=float32),
#  '892': array([-0.18244874, -0.22493437], dtype=float32),
#  '893': array([ 0.24417272, -0.33634695], dtype=float32),
#  '894': array([ 0.24710292, -0.1967923 ], dtype=float32),
#  '895': array([0.12582175, 0.04119573], dtype=float32),
#  '896': array([ 0.07653445, -0.29547068], dtype=float32),
#  '897': array([ 0.07238442, -0.40339693], dtype=float32),
#  '898': array([ 0.2976667 , -0.40158015], dtype=float32),
#  '899': array([ 0.31527686, -0.37013558], dtype=float32),
#  '900': array([ 0.30839825, -0.32603073], dtype=float32),
#  '901': array([ 0.08235183, -0.23554492], dtype=float32),
#  '902': array([ 0.18039915, -0.21366829], dtype=float32),
#  '903': array([ 0.10919622, -0.3727906 ], dtype=float32),
#  '904': array([ 0.24818829, -0.37465578], dtype=float32),
#  '905': array([ 0.31326473, -0.5365688 ], dtype=float32),
#  '906': array([ 0.31332386, -0.26680487], dtype=float32),
#  '907': array([ 0.37332818, -0.34249434], dtype=float32),
#  '908': array([ 0.0678203 , -0.28782985], dtype=float32),
#  '909': array([ 0.24397883, -0.34241158], dtype=float32),
#  '910': array([ 0.1772443, -0.4427196], dtype=float32),
#  '911': array([ 0.09882882, -0.44281358], dtype=float32),
#  '912': array([-0.19716978, -0.23652753], dtype=float32),
#  '913': array([-0.52249634,  0.20981377], dtype=float32),
#  '914': array([ 0.01219738, -0.26861513], dtype=float32),
#  '915': array([ 0.03119332, -0.30963334], dtype=float32),
#  '916': array([ 0.34245342, -0.20363034], dtype=float32),
#  '917': array([ 0.36922616, -0.20306572], dtype=float32),
#  '918': array([ 0.27039593, -0.2939583 ], dtype=float32),
#  '919': array([ 0.12795594, -0.3786055 ], dtype=float32),
#  '920': array([-0.15159494, -0.22970846], dtype=float32),
#  '921': array([ 0.2630382, -0.4666364], dtype=float32),
#  '922': array([ 0.2591389 , -0.33844024], dtype=float32),
#  '923': array([ 0.17204016, -0.3803121 ], dtype=float32),
#  '924': array([ 0.26036382, -0.21333918], dtype=float32),
#  '925': array([ 0.10509725, -0.32283953], dtype=float32),
#  '926': array([ 0.30319998, -0.19333063], dtype=float32),
#  '927': array([-0.12505968, -0.30637822], dtype=float32),
#  '928': array([ 0.3887681 , -0.17297134], dtype=float32),
#  '929': array([ 0.1714356, -0.262148 ], dtype=float32),
#  '930': array([ 0.22193  , -0.2294136], dtype=float32),
#  '931': array([ 0.29072392, -0.307941  ], dtype=float32),
#  '932': array([ 0.32159644, -0.09268102], dtype=float32),
#  '933': array([ 0.49465802, -0.06017941], dtype=float32),
#  '934': array([ 0.18266577, -0.29120675], dtype=float32),
#  '935': array([ 0.28271347, -0.38934156], dtype=float32),
#  '936': array([ 0.19200802, -0.41403434], dtype=float32),
#  '937': array([ 0.17423022, -0.42449686], dtype=float32),
#  '938': array([ 0.12560293, -0.40335348], dtype=float32),
#  '939': array([ 0.32406682, -0.24662495], dtype=float32),
#  '940': array([ 0.10932259, -0.33677915], dtype=float32),
#  '941': array([ 0.09161969, -0.34255138], dtype=float32),
#  '942': array([ 0.11242555, -0.3753947 ], dtype=float32),
#  '943': array([ 0.24354559, -0.39486954], dtype=float32),
#  '944': array([ 0.2010752 , -0.36761037], dtype=float32),
#  '945': array([ 0.36569786, -0.22242007], dtype=float32),
#  '946': array([ 0.12061948, -0.22441274], dtype=float32),
#  '947': array([ 0.19021003, -0.37383932], dtype=float32),
#  '948': array([ 0.27051324, -0.21336809], dtype=float32),
#  '949': array([ 0.432826  , -0.17543304], dtype=float32),
#  '950': array([ 0.32352835, -0.21399769], dtype=float32),
#  '951': array([ 0.46713677, -0.12409854], dtype=float32),
#  '952': array([ 0.15354416, -0.34117004], dtype=float32),
#  '953': array([ 0.40133178, -0.11551383], dtype=float32),
#  '954': array([ 0.33205253, -0.14603844], dtype=float32),
#  '955': array([ 0.15906219, -0.30469748], dtype=float32),
#  '956': array([ 0.31157827, -0.41614646], dtype=float32),
#  '957': array([ 0.32887727, -0.27821577], dtype=float32),
#  '958': array([ 0.09139642, -0.45935914], dtype=float32),
#  '959': array([ 0.03600529, -0.23311275], dtype=float32),
#  '960': array([0.6543393 , 0.13294531], dtype=float32),
#  '961': array([ 0.21407977, -0.38695458], dtype=float32),
#  '962': array([ 0.27517006, -0.1646616 ], dtype=float32),
#  '963': array([ 0.5228652, -0.0521698], dtype=float32),
#  '964': array([ 0.14122751, -0.2989337 ], dtype=float32),
#  '965': array([ 0.4248097 , -0.08096975], dtype=float32),
#  '966': array([ 0.4258802 , -0.10227719], dtype=float32),
#  '967': array([0.42449236, 0.06323102], dtype=float32),
#  '968': array([ 0.1874334, -0.3862938], dtype=float32),
#  '969': array([ 0.35599503, -0.04408823], dtype=float32),
#  '970': array([-0.00672843, -0.24051651], dtype=float32),
#  '971': array([ 0.33641863, -0.03361686], dtype=float32),
#  '972': array([ 0.11954474, -0.26516083], dtype=float32),
#  '973': array([ 0.3537188 , -0.17882112], dtype=float32),
#  '974': array([ 0.25734448, -0.14737311], dtype=float32),
#  '975': array([ 0.2754662 , -0.34560198], dtype=float32),
#  '976': array([-0.0432981 , -0.25176543], dtype=float32),
#  '977': array([-0.19910726, -0.1433892 ], dtype=float32),
#  '978': array([ 0.29899886, -0.36514416], dtype=float32),
#  '979': array([ 0.30682164, -0.39726457], dtype=float32),
#  '980': array([-0.01812124,  0.4606838 ], dtype=float32),
#  '981': array([ 0.1623707 , -0.22389448], dtype=float32),
#  '982': array([ 0.35258946, -0.13304701], dtype=float32),
#  '983': array([ 0.32510936, -0.01676722], dtype=float32),
#  '984': array([-0.05461796, -0.3391932 ], dtype=float32),
#  '985': array([ 0.45849884, -0.25410777], dtype=float32),
#  '986': array([ 0.2103265 , -0.45626327], dtype=float32),
#  '987': array([ 0.2587464, -0.445839 ], dtype=float32),
#  '988': array([ 0.16326597, -0.33552018], dtype=float32),
#  '989': array([ 0.10277504, -0.2024313 ], dtype=float32),
#  '990': array([ 0.13344413, -0.22860177], dtype=float32),
#  '991': array([-0.2681436, -0.1532712], dtype=float32),
#  '992': array([-0.3370632 , -0.17181921], dtype=float32),
#  '993': array([-0.2383057 , -0.10546888], dtype=float32),
#  '994': array([-0.02133571, -0.30327868], dtype=float32),
#  '995': array([-0.11956326, -0.21842459], dtype=float32),
#  '996': array([ 0.09661177, -0.398536  ], dtype=float32),
#  '997': array([-0.2917755 , -0.19514659], dtype=float32),
#  '998': array([ 0.17246431, -0.36206225], dtype=float32),
#  '999': array([ 0.09918585, -0.4356401 ], dtype=float32)}
